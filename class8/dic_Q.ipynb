# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
ans=0
for k,v in dt.items():
    if 12%v == 0:
        ans=+k

print(ans)
# Out:
# 18

# %%
# Q
dt={1:2,2:3,3:4,6:12,17:18,18:12}
l=[]
for i in dt.keys():
    if 12%dt[i] ==0:
        l.append(i)
print(sum(l))
# Out:
# 30

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
print(dt.get(6))
print(dt.get(30))#ye value de deta hai or value na ho to error bhi nahi deta hai
# Out:
# 12
# None

# %% [markdown]
# #SOME FUNCTION

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
del dt[3]
# print(dt)
print(dt.pop(6))
dt.clear()
# Out:
# {1: 2, 2: 3, 6: 12, 17: 18, 18: 12}
# 12

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
x=dt.popitem()#koi bhi aak pair del kar detaa hai 
print(x)
print(dt)
# Out:
# (18, 12)
# {1: 2, 2: 3, 3: 4, 6: 12, 17: 18}

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
dt[6]="hello"
print(dt)
# Out:
# {1: 2, 2: 3, 3: 4, 6: 'hello', 17: 18, 18: 12}

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
s=dt#this is shallo copy 
print(id(dt))
print(id(s))
# Out:
# 1934810914304
# 1934810914304
