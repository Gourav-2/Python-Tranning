# %%
print("hii")
# Out:
# hii

# %% [markdown]
# SET-->
# 1.unordered
# 2. mutable
# 3. uniqac
# 4. index persent nahi hoti hai
# 5. create {}
# 6. set ke andar mutable data type storage nahi kar sakte hai
# 7. set aandar mutable data type stor kar sakte hai
# 8.

# %%
#crud

a={1,2,3,4,5,6,7}
print(a,type(a))

a
# Out:
# {1, 2, 3, 4, 5, 6, 7} <class 'set'>

# %%
#empty set
s=set()

# %%
#creation  of set
a={1,2,3,4,5,6,7,"h"}
print(a,type(a))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'h'} <class 'set'>

# %%
a={1,2,3,4,5,6,7,"h"}
print(a,type(a))
if 9 in a:
    print("yes")
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'h'} <class 'set'>

# %%
#some function 
lst=[1,2,3,4,5,6,6,7,8,7,"h"]
#to remove same element 
lst=set(lst)
lst=list(lst)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'h']

# %%
a={1,2,3,4,5,6,7,"h"}
#if element add karni hai 

# a.add(10)#sigle value ke liaa 
# a.update()
# a.remove(5)#if element present hota hai to discard kar deta our nahi hai to error deta hai  
a.discard(10)#if element present hota hai to discard kar deta our nahi hai to pass kar deta hai 
print(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'h'}
