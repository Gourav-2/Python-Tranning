# %%
print("hello")
# Out:
# hello

# %%
# Q1. Write a Python program to create two sets, A and B, and find the elements
# that are common to both sets.
# A = {1, 2, 3, 4, 5}
# B = {4, 5, 6, 7, 8}

a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
c=a.intersection(b)
print(c)
# Out:
# {4, 5}

# %%
# Write a Python program to create two sets, X and Y, and find the elements
# that are unique to each set (not present in both).
# X = {10, 20, 30, 40}
# Y = {30, 40, 50, 60}

x= {10, 20, 30, 40}
y= {30, 40, 50, 60}

print(x-y)
print(y-x)
# Out:
# {10, 20}
# {50, 60}

# %%
# Write a Python program to check if all elements of one set are contained
# within another set.
# S1 = {1, 2, 3}
# S2 = {1, 2, 3, 4, 5}

s1 = {1, 2, 3}
s2 = {1, 2, 3, 4, 5}

for i in s2:
    if i in s1:
        print("this element present in another element ")
    print(i)
# Out:
# this element present in another element
# 1
# this element present in another element
# 2
# this element present in another element
# 3
# 4
# 5
