# %%
print("hello")
# Out:
# hello

# %%
s={1,2,3,4,4,5,6,}
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#creation of set 
s={1,2,3,4,5,5}
s1=set()#empty set 
print(type(s))
print(type(s1))
# Out:
# <class 'set'>
# <class 'set'>

# %%
s={1,2,3,4,5,5,(1,2,3)}
for i in s:
    print(i, end=" ")
# Out:
# 1 2 3 4 5 (1, 2, 3)

# %%
s.remove(3)
print(s)
# Out:
# {1, 2, 4, 5, (1, 2, 3)}

# %%
s={1,2,3,4,5,5,(1,2,3)}
s.discard(30)
print(s)
# Out:
# {1, 2, 3, 4, 5, (1, 2, 3)}

# %%
s={1,2,3,4,5,6,4,5,8,6,11,2,33,45}
# s.add(100)
# s.add((100,200,300))
# s.update((100,200))
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 33, 8, 100, 200, 11, 45}

# %%
s={1,2,3}
s1={4,5,6,2}
print(s.union(s1)) 
print(s-s1)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 3}
