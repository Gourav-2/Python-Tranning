# %%
#creation of tuple 

tpl=()
tpl1=tuple()
print(type(tpl),type(tpl1))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
x=1,2,3,4  #if variable ko multiple value do to vo tuple  bana jata hai
print(x,type(x))
# Out:
# (1, 2, 3, 4) <class 'tuple'>

# %%
tpl=(1,2,3,5,6,"gourav","gyan")
print(tpl)
# Out:
# (1, 2, 3, 5, 6, 'gourav', 'gyan')

# %%
tpl=(4,5,6,4,5,1,[3,4,5]) #if tuple ke aadar list ho to usko change kar sakte hai 

tpl[-1][1]=44
print(tpl)
# Out:
# (4, 5, 6, 4, 5, 1, [3, 44, 5])

# %%
tpl=(1,3,4,5,6)

print(id(tpl))                        #tuple me change nahi hota lekin new tuple ban jati hai 
tpl+=("hello",5,7,8)
print(tpl)
print(id(tpl))
# Out:
# 1593856283872
# (1, 3, 4, 5, 6, 'hello', 5, 7, 8)
# 1593861722784

# %%
#tupple delete 

tpl=(1,2,3,4,5,6)
print(tpl)

del tpl
print(tpl)
# Out:
# (1, 2, 3, 4, 5, 6)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 print(tpl)
#       6 del tpl
# ----> 7 print(tpl)
#
# NameError: name 'tpl' is not defined

# %%
tpl=(1,2,3,4,5,6)
tpl1=(sorted(tpl,reverse=True))
print(tuple(tpl1))
# Out:
# (6, 5, 4, 3, 2, 1)
