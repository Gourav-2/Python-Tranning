# %%
print("hello")

# %%
mystring="python tutorial"
print(mystring[-3:-8:-1])
print(mystring[-2:-4:-1])
# Out:
# irotu
# ai

# %%
x="gourav"
for i in x:
    print(i)
# Out:
# g
# o
# u
# r
# a
# v
# ['v', 'u', 'r', 'o', 'g', 'a']

# %%
x="gourav"
print(x.upper())
# Out:
# GOURAV

# %%
#spilt

str1="hello my name is gourav"
str2=str1.split( " ")
print(str2)
# Out:
# ['hello', 'my', 'name', 'is', 'gourav']

# %%
#if list ko string me change karna hai to 
lst=['hello', 'my', 'name', 'is', 'gourav']
str1=" ".join(lst)
print(str1)
# Out:
# hello my name is gourav

# %%
#find
str1="hello my name is gourav"
print(str1.find("my"))
# Out:
# 6

# %%
#replace
str1="hello my name is gourav"
str2=str1.replace("gourav","nishant")
print(str2)
# Out:
# hello my name is nishant

# %%
#
