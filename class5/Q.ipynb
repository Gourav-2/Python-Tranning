# %%
print("hello")
# Out:
# hello

# %%
#Q1
lst=[[1,2,3],[3,4,5],[3,4,5],[5,7,3,2]]
lst1=[sum(i) for i in lst]
print(lst1)
# Out:
# [6, 12, 12, 17]

# %%
# Q2
lst=[[1,2,3],[3,4,5],[3,4,5],[5,7,3,2]]
lst_min=[min(i) for i in lst ]
print(lst_min)
# Out:
# [1, 3, 3, 2]

# %%
# Q3

col1=["red","orange","green","blue","white"]
col2=["black","yellow","green","blue"]
lst1=[]
lst2=[]
for i in col1:
    if i not in col2:
        lst1.append(i)

for j in col2:
    if j not in col1:
        lst2.append(j)


print(lst1)
print(lst2)
# Out:
# ['red', 'orange', 'white']
# ['black', 'yellow']

# %%
lst=[0,0,1,2,3,4,4,5,6,6,7,8,8,9,4,4]
result=[]
for i in lst:
    if result==[]:
        result.append(i)
    elif

# %%
lst = [0,0,1,2,3,4,4,5,6,6,7,8,8,9,4,4]
ans=[]
temp=[lst[0]]
for i in range(1,len(lst)):
    if lst[i-1]==lst[i]:
        temp.append(lst[i])
    else:
        ans.append(temp)
        temp=[lst[i]]

print(ans)
# Out:
# [[0, 0], [1], [2], [3], [4, 4], [5], [6, 6], [7], [8, 8], [9]]

# %%
lst = [0,0,1,2,3,4,4,5,6,6,7,8,8,9,4,4]
ans=[]
for i in range(0,len(lst)):
    if
