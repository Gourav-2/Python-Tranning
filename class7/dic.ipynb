# %%
print("hello")
# Out:
# hello

# %% [markdown]
# *dictionary
# 1. mutable
# 2. elemnt store in key and value pair

# %%
dic={"name":["gourav","nishant","harsh"],"marks":[44,55,66]}

# %%
#creating empty dictionary
dt={}
dt1=dict()
print(type(dt),type(dt1))
# Out:
# <class 'dict'> <class 'dict'>

# %%
import pandas as pd

dic={"name":["gourav","nishant","harsh"],"marks":[44,55,66]}
df=pd.DataFrame(dic)
print(df)
# Out:
#       name  marks
# 0   gourav     44
# 1  nishant     55
# 2    harsh     66

# %%
dic={"name":["gourav","nishant","harsh"],"marks":[44,55,66]}

# %%
#tuple
dt={["gourav","harsh"]:[55,65]}
print(dt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #tuple
# ----> 2 dt={["gourav","harsh"]:[55,65]}
#       3 print(dt)
#
# TypeError: unhashable type: 'list'

# %%
dic={"name":["gourav","nishant","harsh"],"marks":[44,55,66]}
if "nam" in dic:
    print("yse")
else:print("no")
# Out:
# no

# %%
#dictionary function 
dt={"name":["gourav","nishant","harsh"],"marks":[44,55,66]}
# print(dt.keys())#if all key acess kar sakta hai
# print(dt.values())#if all value acess kar sakta hai
# print(dt.items())#all item la deta hai
# for i in dt:
#     print(i)
for k,v in dt.items():
    print(k,v)
# Out:
# name ['gourav', 'nishant', 'harsh']
# marks [44, 55, 66]

# %%
dt1={}
